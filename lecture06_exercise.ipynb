# %% [markdown]
# # Lecture 6 — Class Exercise
# ## Part-to-Whole: Hierarchical Visualization
#
# > **Push to:** `week06/lecture06_exercise.ipynb`
#
# **Rules:**
# 1. Use `px` first, then customise with `update_traces` / `update_layout`
# 2. Colour encodes a meaningful category — not decoration
# 3. Insight title names the specific finding
# 4. Consider: would a bar chart be clearer? If yes, use the bar chart
#
# ---

# %%
import pandas as pd
import plotly.express as px
import numpy as np

# Dataset: Global Energy Mix by Country and Source
df = pd.read_csv('../data/global_energy_mix.csv')

# Source type mapping — reuse from lecture
source_category = {
    'Coal': 'Fossil', 'Oil': 'Fossil', 'Natural Gas': 'Fossil',
    'Nuclear': 'Low-carbon', 'Hydro': 'Low-carbon',
    'Wind': 'Renewable', 'Solar': 'Renewable', 'Other Renewables': 'Renewable'
}
df['Source_Type'] = df['Source'].map(source_category)

print(f"Loaded: {len(df)} rows")
print(df.head(10))

# %% [markdown]
# ## Task 1 — Treemap: fossil fuel dependency by country
#
# **What to build:** A treemap showing **fossil fuel TWh only**, broken down by Region → Country → Source (Coal / Oil / Natural Gas).
#
# **Requirements:**
# - Filter to fossil sources only before plotting
# - Use `path=['Region', 'Country', 'Source']` for the hierarchy
# - Colour encodes the fossil source type (Coal / Oil / Natural Gas) with a CVD-safe palette
# - Show TWh values in labels — no percentages
# - Grey out parent nodes (Region and Country level)
# - Insight title naming which region or country is most fossil-dependent
#
# > 💡 `df.loc[df['Source_Type'] == 'Fossil']`

# %%
# Task 1
fossil = df[df['Source_Type'] == 'Fossil'].copy()
fossil_agg = fossil.groupby(['Region', 'Country', 'Source'], as_index=False)['TWh'].sum()

fossil_colors = {'Coal': '#4D4D4D', 'Oil': '#E63946', 'Natural Gas': '#2E75B6'}  # CVD-safe

fig1 = px.treemap(
    fossil_agg, path=['Region', 'Country', 'Source'], values='TWh',
    color='Source', color_discrete_map=fossil_colors,
    title="Asia is the most fossil-fuel-dependent region, led by Saudi Arabia's oil and gas output"
)
fig1.update_traces(texttemplate='%{label}<br>%{value:.0f} TWh')
# Grey out parent nodes (Region and Country level) — only leaf (Source) nodes keep their category colour
fig1.update_traces(
    marker_colors=[fossil_colors.get(label, '#CCCCCC') for label in fig1.data[0].labels]
)
fig1.update_layout(font=dict(family='Arial', size=12), margin=dict(t=60, l=0, r=0, b=0))
fig1.show()

# %% [markdown]
# ## Task 2 — Sunburst: tipping behaviour by day and meal time
#
# **What to build:** A sunburst chart using the built-in `tips` dataset showing how **total bill amount** is distributed across day → time → smoker status.
#
# **Requirements:**
# - Load tips with `px.data.tips()`
# - Aggregate **total bill** (sum of `total_bill`) per group — not count
# - Hierarchy: `path=['day', 'time', 'smoker']`
# - Colour encodes smoker status with a CVD-safe blue/orange palette
# - Grey out parent nodes (day and time level)
# - Use `percent parent` for text labels
# - Insight title describing where the most spending happens
#
# > 💡 `tips.groupby(['day', 'time', 'smoker'])['total_bill'].sum().reset_index()`

# %%
# Task 2
import plotly.graph_objects as go

tips = px.data.tips()
tips_agg = tips.groupby(['day', 'time', 'smoker'], observed=True)['total_bill'].sum().reset_index()

# Build the hierarchy manually so parent nodes (day, time) can be forced grey —
# px.sunburst's automatic colour mapping only controls leaf-level colour
ids, labels, parents, values, colors = [], [], [], [], []
smoker_colors = {'Yes': '#F4A261', 'No': '#2E75B6'}  # CVD-safe orange/blue

for day in tips_agg['day'].unique():
    ids.append(str(day)); labels.append(str(day)); parents.append(''); values.append(0)
    colors.append('#CCCCCC')  # grey parent node
    for time in tips_agg.loc[tips_agg['day'] == day, 'time'].unique():
        day_time_id = f"{day}-{time}"
        ids.append(day_time_id); labels.append(str(time)); parents.append(str(day)); values.append(0)
        colors.append('#CCCCCC')  # grey parent node
        sub = tips_agg[(tips_agg['day'] == day) & (tips_agg['time'] == time)]
        for _, row in sub.iterrows():
            leaf_id = f"{day_time_id}-{row['smoker']}"
            ids.append(leaf_id); labels.append(str(row['smoker'])); parents.append(day_time_id)
            values.append(row['total_bill']); colors.append(smoker_colors.get(row['smoker'], '#CCCCCC'))

fig2 = go.Figure(go.Sunburst(
    ids=ids, labels=labels, parents=parents, values=values,
    branchvalues='remainder',  # parent value (0) + children = parent's ring size
    marker=dict(colors=colors),
    textinfo='label+percent parent'
))
fig2.update_layout(
    title='Saturday and Sunday dinners bring in the most total spending across the week',
    font=dict(family='Arial', size=12), margin=dict(t=60, l=0, r=0, b=0)
)
fig2.show()

# %% [markdown]
# ## Task 3 — Treemap vs bar: low-carbon energy by country
#
# **What to build:** Build **both** a treemap and a horizontal bar chart showing total low-carbon TWh (Nuclear + Hydro) per country. Then answer the question in a markdown cell below.
#
# **Requirements:**
# - Filter to `Source_Type == 'Low-carbon'` and aggregate TWh by country
# - Treemap: single-level `path=['All', 'Country']` with a dummy root node labelled `'Low-carbon'`
# - Bar chart: sorted by TWh, horizontal orientation, CVD-safe colour
# - Both charts show TWh values, not percentages
# - Insight title on the bar chart naming the leading country

# %%
# Task 3 — charts
low_carbon = df[df['Source_Type'] == 'Low-carbon'].groupby('Country', as_index=False)['TWh'].sum()
low_carbon['All'] = 'Low-carbon'  # dummy root for single-level treemap

fig3a = px.treemap(
    low_carbon, path=['All', 'Country'], values='TWh',
    color_discrete_sequence=['#2E75B6'],  # single hue — one metric, not a category comparison
    title='France leads global low-carbon generation, driven by its nuclear fleet'
)
fig3a.update_traces(texttemplate='%{label}<br>%{value:.0f} TWh')
fig3a.update_layout(font=dict(family='Arial', size=12), margin=dict(t=60, l=0, r=0, b=0))
fig3a.show()

low_carbon_sorted = low_carbon.sort_values('TWh')
fig3b = px.bar(
    low_carbon_sorted, x='TWh', y='Country', orientation='h',
    color_discrete_sequence=['#2E75B6'],  # CVD-safe single hue, ordered by value
    labels={'TWh': 'Low-Carbon Generation (TWh)', 'Country': ''},
    title='France leads global low-carbon generation, driven by its nuclear fleet'
)
fig3b.update_layout(plot_bgcolor='white', paper_bgcolor='white', font=dict(family='Arial', size=12))
fig3b.update_traces(marker_line_width=0)
fig3b.show()

# %% [markdown]
# **Which is clearer — the treemap or the bar chart?**
#
# The bar chart is clearer here. With only 10 countries and a single metric (TWh), a sorted horizontal bar lets you read and compare exact magnitudes at a glance and rank countries precisely — something a treemap's area-based encoding makes much harder to judge by eye. Treemaps earn their place when there's a genuine hierarchy to show (as in Task 1's Region → Country → Source breakdown); for a flat, single-level ranking like this one, the extra visual complexity of a treemap doesn't add anything a bar chart doesn't already do better.
